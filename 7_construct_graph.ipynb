# %% [markdown]
# # Get root nodes from CXRGraph

# %%
import bisect
from collections import Counter, defaultdict

from datasets import load_from_disk
from tqdm import tqdm
import os

# %%
class Entity:
    def __init__(self, start, end, label, sent_id, tok_list=None, tok_str=None):
        self.id = None
        self.tok_indices = [start, end]
        self.label = label

        self.sent_id = sent_id
        if tok_list:
            self.tok_list = tok_list
            self.tok_str = " ".join(tok_list) if not tok_str else tok_str
        elif tok_str:
            self.tok_str = tok_str
            self.tok_list = tok_str.split(" ")

        if "Observation" in label:
            self.label_type = "OBS"
        elif "Anatomy" == label:
            self.label_type = "ANAT"
        else:
            self.label_type = "LOCATT"

        self.attr_normal = "NA"
        self.attr_action = "NA"
        self.attr_change = "NA"

        self.chain_info = {
            "modify": {"from": [], "to": []},
            "part_of": {"from": [], "to": []},
            "located_at": {"from": [], "to": []},
            "suggestive_of": {"from": [], "to": []},
        }

    def __repr__(self) -> str:
        # return f"{self.tok_str} {self.tok_indices}: {self.label}, {self.attr_normal, self.attr_action, self.attr_change}"
        return f"{self.tok_str}"

    def __str__(self) -> str:
        return self.__repr__()

    def __eq__(self, other):
        if isinstance(other, Entity):
            return self.tok_indices == other.tok_indices
        else:
            return other == self.tok_indices

    def __hash__(self):
        return hash(str(self.tok_indices))


class Relation:
    def __init__(self, subj_ent, obj_ent, label):
        self.label = label
        self.subj_ent = subj_ent
        self.obj_ent = obj_ent

    def __repr__(self) -> str:
        return f"{self.subj_ent.tok_str} {self.label} {self.obj_ent.tok_str}"

    def __str__(self) -> str:
        return self.__repr__()


class LinkedGraph:
    def __init__(self, ents):
        self.id = None
        self.ents = sorted(ents, key=lambda x: x.tok_indices[0])
        self.rels = []
        self.sent_id = ents[0].sent_id

        assert len(set([i.sent_id for i in ents])) == 1

    def get_involved_rels(self, rel_list):
        target_rels = []
        in_used_ents = set()
        for rel in rel_list:
            if rel.subj_ent in self.ents and rel.obj_ent in self.ents:
                target_rels.append(rel)
                in_used_ents.update([rel.subj_ent, rel.obj_ent])
        self.rels = target_rels

    def __repr__(self) -> str:
        return f"{[i.tok_str for i in self.ents]}"

    def __str__(self) -> str:
        return self.__repr__()

# %%
def search_linked_ents(curr_ent, visited, group):
    visited.add(curr_ent)
    group.append(curr_ent)
    neighbors = [ent for nested_dict in curr_ent.chain_info.values() for adjacent_ents in nested_dict.values() for ent in adjacent_ents]
    for next_ent in neighbors:
        if next_ent not in visited:
            search_linked_ents(next_ent, visited, group)


def max_coverage_spans(spans):
    if not spans:
        return [], [], 0

    # 按结束时间升序排序
    sorted_spans = sorted(spans, key=lambda x: x[1])
    n = len(sorted_spans)
    starts = [s[0] for s in sorted_spans]
    ends = [s[1] for s in sorted_spans]
    lengths = [e - s for s, e in sorted_spans]

    # 预处理j_values数组，记录每个i对应的最大的j，使得 ends[j] <= starts[i]
    j_values = []
    for i in range(n):
        start_i = starts[i]
        j = bisect.bisect_right(ends, start_i) - 1  # 二分查找, 找到第一个`大于`start_i的位置
        j_values.append(j)

    # 构建 dp 数组，其中 dp[i] 表示前 i+1 个 span 的最大总覆盖率。通过比较包含当前 span 和不包含当前 span 的情况，确定最优解。
    # dp记录了选中下一个span之后的总覆盖率
    dp = [0] * n
    dp[0] = lengths[0]
    for i in range(1, n):
        j = j_values[i]
        current = lengths[i] + (dp[j] if j >= 0 else 0)
        dp[i] = max(dp[i - 1], current)

    # 回溯找出选中的span。从最后一个span开始，如果当前span被选中，则跳到j_values[i]对应的span
    # 当dp发生变化时，说明
    selected_indices = []
    i = n - 1
    while i >= 0:
        if i == 0:
            if dp[i] == lengths[i]:
                selected_indices.append(i)
            break
        if dp[i] > dp[i - 1]:
            selected_indices.append(i)
            i = j_values[i]
        else:
            i -= 1

    selected_indices.reverse()
    selected_spans = [sorted_spans[i] for i in selected_indices]
    total_coverage = dp[-1]

    return selected_indices, selected_spans, total_coverage


def resolve_ent_rel(split_sent_idx, cxrgraph_ent_lst, cxrgraph_rel_lst, cxrgraph_attr_lst, radlex_lst):
    # Entity and Relation 使用的是cxrgraph的结果，radlex则是用来 normalize cxrgraph的ent
    ent_list = []
    rel_list = []
    for ent in cxrgraph_ent_lst:
        ent = Entity(start=ent["tok_indices"][0], end=ent["tok_indices"][1], label=ent["ent_type"], tok_list=ent["ent_toks"], sent_id=split_sent_idx)
        ent_list.append(ent)
    for attr in cxrgraph_attr_lst:
        ent = ent_list[ent_list.index(attr["tok_indices"])]
        ent.attr_normal = attr["attr_normality"]
        ent.attr_action = attr["attr_action"]
        ent.attr_change = attr["attr_change"]
    for rel in cxrgraph_rel_lst:
        subj_ent = ent_list[ent_list.index(rel["subj_tok_indices"])]
        obj_ent = ent_list[ent_list.index(rel["obj_tok_indices"])]
        label = rel["rel_type"]
        subj_ent.chain_info[label]["to"].append(obj_ent)
        obj_ent.chain_info[label]["from"].append(subj_ent)
        rel_list.append(Relation(subj_ent, obj_ent, label))

    # Set ent id
    for ent_idx, ent in enumerate(sorted(ent_list, key=lambda x: x.tok_indices[0])):
        ent.id = f"E{ent_idx}"

    # 选择覆盖率最大的radlex子集
    radlex_ent_indices = [node["tok_indices"] for node in radlex_lst]
    selected_idx_list, _, _ = max_coverage_spans(radlex_ent_indices)

    # 用radlex的ent替换cxrgraph的ent
    for radlex_idx in selected_idx_list:
        radlex_ent = radlex_lst[radlex_idx]
        merged_cxrgraph_ents = []
        for cxrgraph_ent in ent_list:
            # 如果cxrgrpah被radlex包含，那么就加入候选集等待替换；如果cxrgraph和radlex有交集，那么就跳过这个radlex
            pos_ab = check_span_relation(cxrgraph_ent.tok_indices, radlex_ent["tok_indices"])
            if pos_ab in ["equal", "inside"]:
                merged_cxrgraph_ents.append(cxrgraph_ent)
            elif pos_ab == "overlap":
                break
            else:
                continue

        # 如果merged_cxrgraph_ents不为空，那么就用radlex替换候选集的cxrgraph ent
        if merged_cxrgraph_ents:
            inherited_label = get_label_inheritance(merged_cxrgraph_ents)
            inherited_attr_dict = get_attr_inheritance(merged_cxrgraph_ents)

            new_ent = Entity(start=radlex_ent["tok_indices"][0], end=radlex_ent["tok_indices"][1], label=inherited_label, tok_str=radlex_ent["radlex_name"], sent_id=split_sent_idx)
            new_ent.attr_normal = inherited_attr_dict["normality"]
            new_ent.attr_action = inherited_attr_dict["action"]
            new_ent.attr_change = inherited_attr_dict["change"]
            new_ent.id = radlex_ent["radlex_id"]

            # inherit chain info
            for cxrgraph_ent in merged_cxrgraph_ents:
                for rel_type, from_to_dict in cxrgraph_ent.chain_info.items():
                    # 把merged_cxrgraph_ents的from和to的关系都继承过来，如果是内部ents之间指向关系，那么就跳过
                    for key, value_lst in from_to_dict.items():
                        for value in value_lst:
                            if value not in merged_cxrgraph_ents:
                                new_ent.chain_info[rel_type][key].append(value)

            # replace from ent_list
            ent_list.append(new_ent)
            for cxrgraph_ent in merged_cxrgraph_ents:
                ent_list.remove(cxrgraph_ent)

            # replace from rel_list
            # pleural_effusion 应该把 pleural 和 effusion 都替换掉。在rel中则包括：
            #   opacifications suggestive_of effusions
            #   bilateral modify pleural
            #   effusions located_at pleural
            rel_objs_tobe_removed = []
            for rel in rel_list:
                if rel.subj_ent in merged_cxrgraph_ents and rel.obj_ent in merged_cxrgraph_ents:
                    # 关于 from 和 to 的关系链，在新的ent中已经继承了，所以这里不需要处理
                    rel_objs_tobe_removed.append(rel)
                elif rel.subj_ent in merged_cxrgraph_ents:
                    # subj need to be replaced
                    rel.obj_ent.chain_info[rel.label]["from"].remove(rel.subj_ent)
                    rel.obj_ent.chain_info[rel.label]["from"].append(new_ent)
                    rel.subj_ent = new_ent
                elif rel.obj_ent in merged_cxrgraph_ents:
                    rel.subj_ent.chain_info[rel.label]["to"].remove(rel.obj_ent)
                    rel.subj_ent.chain_info[rel.label]["to"].append(new_ent)
                    rel.obj_ent = new_ent

            for rel in rel_objs_tobe_removed:
                rel_list.remove(rel)

    assert len(rel_list) == len(set(rel_list)), f"{rel_list}"
    return ent_list, rel_list


def get_label_inheritance(cxrgraph_ents):
    candi_labels = [ent.label for ent in cxrgraph_ents]
    if "Observation-Absent" in candi_labels:
        return "Observation-Absent"
    elif "Observation-Uncertain" in candi_labels:
        return "Observation-Uncertain"
    elif "Observation-Present" in candi_labels:
        return "Observation-Present"
    elif "Aanatomy" in candi_labels:
        return "Aanatomy"
    else:
        return "Location-Attribute"


def get_attr_inheritance(cxrgraph_ents):
    candi_attr_normal = [ent.attr_normal for ent in cxrgraph_ents]
    candi_attr_action = [ent.attr_action for ent in cxrgraph_ents]
    candi_attr_change = [ent.attr_change for ent in cxrgraph_ents]
    assert all([i[0].istitle() for i in candi_attr_change]), f"{candi_attr_change} {candi_attr_normal} {candi_attr_action}"

    output_attr = {"normality": "NA", "action": "NA", "change": "NA"}
    if "Normal" in candi_attr_normal:
        output_attr["normality"] = "Normal"
    elif "Abnormal" in candi_attr_normal:
        output_attr["normality"] = "Abnormal"

    if "Essential" in candi_attr_action:
        output_attr["action"] = "Essential"
    elif "Removable" in candi_attr_action:
        output_attr["action"] = "Removable"

    if "Positive" in candi_attr_change:
        output_attr["change"] = "Positive"
    elif "Negative" in candi_attr_change:
        output_attr["change"] = "Negative"
    elif "Unchanged" in candi_attr_change:
        output_attr["change"] = "Unchanged"

    return output_attr


def check_span_relation(ent_a_indices, ent_b_indices):
    if ent_a_indices[1] <= ent_b_indices[0]:
        return "before"
    elif ent_a_indices[0] >= ent_b_indices[1]:
        return "after"
    elif ent_a_indices[0] == ent_b_indices[0] and ent_a_indices[1] == ent_b_indices[1]:
        return "equal"
    elif ent_a_indices[0] <= ent_b_indices[0] and ent_b_indices[1] <= ent_a_indices[1]:
        return "contain"
    elif ent_b_indices[0] <= ent_a_indices[0] and ent_a_indices[1] <= ent_b_indices[1]:
        return "inside"
    else:
        return "overlap"

# %%
class SentenceRepresentation:
    def __init__(self, doc_key, sent_id, sent_text):
        self.doc_key = doc_key
        self.sent_id = sent_id
        self.sent_text = sent_text
        self.ent_tuples = []  # (tok_str, label, attr_normal, attr_action, attr_change)
        self.rel_tuples = []  # (subj_tok_str, label, obj_tok_str)

    def set_sent_repr(self, linked_graphs):
        for linked_graph in linked_graphs:
            for ent in linked_graph.ents:
                if ent.attr_action == "Removable":
                    continue
                self.ent_tuples.append((ent.tok_str, ent.label, ent.attr_normal, ent.attr_action, ent.attr_change))

            for rel in linked_graph.rels:
                if rel.subj_ent.attr_action == "Removable" or rel.obj_ent.attr_action == "Removable":
                    continue
                self.rel_tuples.append((rel.subj_ent.tok_str, rel.label, rel.obj_ent.tok_str))

    def __repr__(self) -> str:
        return f"{self.sent_text}"

    def __str__(self) -> str:
        return self.__repr__()


class ReprTuple:
    def __init__(self, repr_tuples):
        self.repr_tuples = tuple(sorted(tuple(sorted(inner)) if isinstance(inner, list) else inner for inner in repr_tuples))

    def __hash__(self):
        # 直接对已经排序的嵌套元组进行哈希
        return hash(self.repr_tuples)

    def __eq__(self, other):
        # 比较两个对象的 repr_tuples 是否相等
        if isinstance(other, ReprTuple):
            return self.repr_tuples == other.repr_tuples
        return False

    def __repr__(self):
        return f"ReprTuple({self.repr_tuples})"

# %% [markdown]
# # Create dataset

# %%
def add_graph_repr(doc):
    reprs = []
    for split_sent_idx, (cxrgraph_ent, cxrgraph_rel, cxrgraph_attr, radlex) in enumerate(zip(doc["cxrgraph_ent"], doc["cxrgraph_rel"], doc["cxrgraph_attr"], doc["radlex"])):

        sent_repr = SentenceRepresentation(doc_key=doc["doc_key"], sent_id=split_sent_idx, sent_text=doc["split_sents"][split_sent_idx])

        # resolve ent and rel from json
        ent_list, rel_list = resolve_ent_rel(split_sent_idx, cxrgraph_ent, cxrgraph_rel, cxrgraph_attr, radlex)

        linked_graphs = []
        visited_ents = set()
        for ent in ent_list:
            if ent not in visited_ents:
                sent_ents = []
                search_linked_ents(ent, visited_ents, sent_ents)
                sent_graph = LinkedGraph(sent_ents)
                sent_graph.get_involved_rels(rel_list)
                linked_graphs.append(sent_graph)

        sent_repr.set_sent_repr(linked_graphs)
        reprs.append(sent_repr)

    doc["graph_reprs"] = []
    for sent_repr in reprs:
        doc["graph_reprs"].append([sent_repr.ent_tuples, sent_repr.rel_tuples])
    return doc

# %%
input_dir = "/home/yuxiang/liao/workspace/arrg_preprocessing/outputs/interpret_text/all/"
output_dir = "/home/yuxiang/liao/workspace/arrg_preprocessing/outputs/interpret_graph/all/"

for section_name in ["findings", "impression"]:
    ds_text = load_from_disk(os.path.join(input_dir, f"interpret_text_{section_name}"))
    ds_graph = ds_text.map(add_graph_repr)
    ds_graph.save_to_disk(os.path.join(output_dir, f"interpret_graph_{section_name}"))
# Out:
# Map: 100%|██████████| 343738/343738 [07:38<00:00, 750.12 examples/s]
# Map: 100%|██████████| 8825/8825 [00:11<00:00, 745.81 examples/s]
# Map: 100%|██████████| 2692/2692 [00:05<00:00, 510.14 examples/s]
# Saving the dataset (7/7 shards): 100%|██████████| 343738/343738 [00:08<00:00, 39128.71 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 8825/8825 [00:00<00:00, 65651.08 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2692/2692 [00:00<00:00, 37634.38 examples/s]
# Map: 100%|██████████| 365565/365565 [07:14<00:00, 841.99 examples/s]
# Map: 100%|██████████| 9308/9308 [00:11<00:00, 827.41 examples/s]
# Map: 100%|██████████| 2965/2965 [00:03<00:00, 925.22 examples/s]
# Saving the dataset (7/7 shards): 100%|██████████| 365565/365565 [00:02<00:00, 167831.04 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 9308/9308 [00:00<00:00, 95623.01 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2965/2965 [00:00<00:00, 67678.41 examples/s]

# %%
ds_graph["test"]["graph_reprs"][0]
# Out:
# [[[['significant', 'Observation-Absent', 'NA', 'NA', 'NA'],
#    ['cardiovascular', 'Observation-Absent', 'NA', 'NA', 'NA'],
#    ['abnormalities', 'Observation-Absent', 'NA', 'NA', 'NA']],
#   [['significant', 'modify', 'abnormalities'],
#    ['abnormalities', 'located_at', 'cardiovascular']]],
#  [[['significant', 'Observation-Absent', 'NA', 'NA', 'NA'],
#    ['pulmonary', 'Anatomy', 'NA', 'NA', 'NA'],
#    ['abnormalities', 'Observation-Absent', 'NA', 'NA', 'NA']],
#   [['significant', 'modify', 'abnormalities'],
#    ['abnormalities', 'located_at', 'pulmonary']]],
#  [[['pleural effusion', 'Observation-Absent', 'NA', 'NA', 'NA'],
#    ['reaching', 'Location-Attribute', 'NA', 'NA', 'NA'],
#    ['lateral', 'Location-Attribute', 'NA', 'NA', 'NA'],
#    ['pleural', 'Anatomy', 'NA', 'NA', 'NA'],
#    ['paranasal sinuses', 'Location-Attribute', 'NA', 'NA', 'NA']],
#   [['pleural effusion', 'located_at', 'reaching'],
#    ['reaching', 'located_at', 'paranasal sinuses'],
#    ['lateral', 'modify', 'pleural'],
#    ['paranasal sinuses', 'part_of', 'pleural']]],
#  [[['minor', 'Observation-Uncertain', 'NA', 'NA', 'NA'],
#    ['pleural effusion', 'Observation-Uncertain', 'NA', 'NA', 'NA']],
#   [['minor', 'modify', 'pleural effusion']]],
#  [[['posterior', 'Location-Attribute', 'NA', 'NA', 'NA'],
#    ['pleural', 'Anatomy', 'NA', 'NA', 'NA'],
#    ['paranasal sinuses', 'Location-Attribute', 'NA', 'NA', 'NA'],
#    ['possibly', 'Observation-Uncertain', 'NA', 'NA', 'NA'],
#    ['present', 'Observation-Uncertain', 'NA', 'NA', 'NA']],
#   [['posterior', 'modify', 'pleural'],
#    ['paranasal sinuses', 'located_at', 'pleural'],
#    ['possibly', 'located_at', 'paranasal sinuses'],
#    ['present', 'modify', 'possibly'],
#    ['present', 'located_at', 'paranasal sinuses']]]]

# %% [markdown]
# # Statistics

# %%
def get_repr_tuples(hf_dataset, data_split):
    reprs = []
    for doc in tqdm(hf_dataset[data_split]):
        for split_sent_idx, (cxrgraph_ent, cxrgraph_rel, cxrgraph_attr, radlex) in enumerate(zip(doc["cxrgraph_ent"], doc["cxrgraph_rel"], doc["cxrgraph_attr"], doc["radlex"])):

            sent_repr = SentenceRepresentation(doc_key=doc["doc_key"], sent_id=split_sent_idx, sent_text=doc["split_sents"][split_sent_idx])

            # resolve ent and rel from json
            ent_list, rel_list = resolve_ent_rel(split_sent_idx, cxrgraph_ent, cxrgraph_rel, cxrgraph_attr, radlex)

            linked_graphs = []
            visited_ents = set()
            for ent in ent_list:
                if ent not in visited_ents:
                    sent_ents = []
                    search_linked_ents(ent, visited_ents, sent_ents)
                    sent_graph = LinkedGraph(sent_ents)
                    sent_graph.get_involved_rels(rel_list)
                    linked_graphs.append(sent_graph)

            sent_repr.set_sent_repr(linked_graphs)
            reprs.append(sent_repr)

    return reprs

# %%
def print_statistic(reprs, data_split):
    sents = Counter()
    sent_tuples = Counter()
    tuples = Counter()
    ent_texts = Counter()

    sent_tuples_rm_attr = Counter()
    tuples_rm_attr = Counter()
    ent_texts_rm_attr = Counter()

    for sent_repr in reprs:
        sents.update([sent_repr.sent_text])
        repr_tuple = ReprTuple(sent_repr.ent_tuples + sent_repr.rel_tuples)
        sent_tuples.update([repr_tuple])
        tuples.update(repr_tuple.repr_tuples)
        ent_texts.update([ent[0] for ent in sent_repr.ent_tuples])

        repr_tuple_rm_attr = ReprTuple([ent[:2] for ent in sent_repr.ent_tuples] + sent_repr.rel_tuples)
        sent_tuples_rm_attr.update([repr_tuple_rm_attr])
        tuples_rm_attr.update(repr_tuple_rm_attr.repr_tuples)
        ent_texts_rm_attr.update([ent[0] for ent in [ent[:2] for ent in sent_repr.ent_tuples]])

    print(f"[{data_split}] Total sents: {len(reprs)}")
    print(f"[{data_split}] Unique sents: {len(sents)}")
    print(f"[{data_split}] Unique sent tuples: {len(sent_tuples)}")
    print(f"[{data_split}] Unique tuples: {len(tuples)}")
    print(f"[{data_split}] Unique ent texts: {len(ent_texts)}")
    print()
    print(f"[{data_split}] Unique sent tuples (rm attr): {len(sent_tuples_rm_attr)}")
    print(f"[{data_split}] Unique tuples (rm attr): {len(tuples_rm_attr)}")
    print(f"[{data_split}] Unique ent texts (rm attr): {len(ent_texts_rm_attr)}")
    print()

# %%
ds_text = load_from_disk("/home/yuxiang/liao/workspace/arrg_preprocessing/outputs/interpret_text/all/interpret_text_findings")
ds_text["train"][1]
# Out:
# {'doc_key': 'train#134#findings',
#  'sents': ['Single view chest dated 2/11/2000 at 20:11 hours: Unchanged appearance of left basilar opacity, which may represent atelectasis versus consolidation.',
#   'No pleural effusion or pneumothorax.',
#   'Unchanged moderate cardiomegaly.',
#   'Radiopaque marker corresponding to IABP is visualized at level of left eighth posterior rib.',
#   'Unchanged appearance of other lines and tubes, including endotracheal tube, Swan-Ganz catheter with tip in main pulmonary artery, and multiple thoracic drains.',
#   'Radiopaque object over superior mediastinum likely represents retained pacemaker fragment.',
#   'Single view chest dated 2-11-2000: There has been interval placement of a transesophageal echo probe.',
#   'Unchanged appearance of other lines and tubes as described above.',
#   'There is slight interval worsening of left lower lobe opacity, which may represent worsened atelectasis versus consolidation.',
#   'There appears to be a small superimposed left-sided pleural effusion.',
#   'Unchanged appearance of moderate cardiomegaly.'],
#  'sent_toks': [['Single',
#    'view',
#    'chest',
#    'dated',
#    '2/11/2000',
#    'at',
#    '20:11',
#    'hours',
#    ':',
#    'Unchanged',
#    'appearance',
#    'of',
#    'left',
#    'basilar',
#    'opacity',
#    ',',
#    'which',
#    'may',
#    'represent',
#    'atelectasis',
#    'versus',
#    'consolidation',
#    '.'],
#   ['No', 'pleural', 'effusion', 'or', 'pneumothorax', '.'],
#   ['Unchanged', 'moderate', 'cardiomegaly', '.'],
#   ['Radiopaque',
#    'marker',
#    'corresponding',
#    'to',
#    'IABP',
#    'is',
#    'visualized',
#    'at',
#    'level',
#    'of',
#    'left',
#    'eighth',
#    'posterior',
#    'rib',
#    '.'],
#   ['Unchanged',
#    'appearance',
#    'of',
#    'other',
#    'lines',
#    'and',
#    'tubes',
#    ',',
#    'including',
#    'endotracheal',
#    'tube',
#    ',',
#    'Swan',
#    '-',
#    'Ganz',
#    'catheter',
#    'with',
#    'tip',
#    'in',
#    'main',
#    'pulmonary',
#    'artery',
#    ',',
#    'and',
#    'multiple',
#    'thoracic',
#    'drains',
#    '.'],
#   ['Radiopaque',
#    'object',
#    'over',
#    'superior',
#    'mediastinum',
#    'likely',
#    'represents',
#    'retained',
#    'pacemaker',
#    'fragment',
#    '.'],
#   ['Single',
#    'view',
#    'chest',
#    'dated',
#    '2',
#    '-',
#    '11',
#    '-',
#    '2000',
#    ':',
#    'There',
#    'has',
#    'been',
#    'interval',
#    'placement',
#    'of',
#    'a',
#    'transesophageal',
#    'echo',
#    'probe',
#    '.'],
#   ['Unchanged',
#    'appearance',
#    'of',
#    'other',
#    'lines',
#    'and',
#    'tubes',
#    'as',
#    'described',
#    'above',
#    '.'],
#   ['There',
#    'is',
#    'slight',
#    'interval',
#    'worsening',
#    'of',
#    'left',
#    'lower',
#    'lobe',
#    'opacity',
#    ',',
#    'which',
#    'may',
#    'represent',
#    'worsened',
#    'atelectasis',
#    'versus',
#    'consolidation',
#    '.'],
#   ['There',
#    'appears',
#    'to',
#    'be',
#    'a',
#    'small',
#    'superimposed',
#    'left',
#    '-',
#    'sided',
#    'pleural',
#    'effusion',
#    '.'],
#   ['Unchanged', 'appearance', 'of', 'moderate', 'cardiomegaly', '.']],
#  'tok_char_indices': [[[0, 6],
#    [7, 11],
#    [12, 17],
#    [18, 23],
#    [24, 33],
#    [34, 36],
#    [37, 42],
#    [43, 48],
#    [48, 49],
#    [50, 59],
#    [60, 70],
#    [71, 73],
#    [74, 78],
#    [79, 86],
#    [87, 94],
#    [94, 95],
#    [96, 101],
#    [102, 105],
#    [106, 115],
#    [116, 127],
#    [128, 134],
#    [135, 148],
#    [148, 149]],
#   [[150, 152], [153, 160], [161, 169], [170, 172], [173, 185], [185, 186]],
#   [[187, 196], [197, 205], [206, 218], [218, 219]],
#   [[220, 230],
#    [231, 237],
#    [238, 251],
#    [252, 254],
#    [255, 259],
#    [260, 262],
#    [263, 273],
#    [274, 276],
#    [277, 282],
#    [283, 285],
#    [286, 290],
#    [291, 297],
#    [298, 307],
#    [308, 311],
#    [311, 312]],
#   [[313, 322],
#    [323, 333],
#    [334, 336],
#    [337, 342],
#    [343, 348],
#    [349, 352],
#    [353, 358],
#    [358, 359],
#    [360, 369],
#    [370, 382],
#    [383, 387],
#    [387, 388],
#    [389, 393],
#    [393, 394],
#    [394, 398],
#    [399, 407],
#    [408, 412],
#    [413, 416],
#    [417, 419],
#    [420, 424],
#    [425, 434],
#    [435, 441],
#    [441, 442],
#    [443, 446],
#    [447, 455],
#    [456, 464],
#    [465, 471],
#    [471, 472]],
#   [[473, 483],
#    [484, 490],
#    [491, 495],
#    [496, 504],
#    [505, 516],
#    [517, 523],
#    [524, 534],
#    [535, 543],
#    [544, 553],
#    [554, 562],
#    [562, 563]],
#   [[564, 570],
#    [571, 575],
#    [576, 581],
#    [582, 587],
#    [588, 589],
#    [589, 590],
#    [590, 592],
#    [592, 593],
#    [593, 597],
#    [597, 598],
#    [599, 604],
#    [605, 608],
#    [609, 613],
#    [614, 622],
#    [623, 632],
#    [633, 635],
#    [636, 637],
#    [638, 653],
#    [654, 658],
#    [659, 664],
#    [664, 665]],
#   [[666, 675],
#    [676, 686],
#    [687, 689],
#    [690, 695],
#    [696, 701],
#    [702, 705],
#    [706, 711],
#    [712, 714],
#    [715, 724],
#    [725, 730],
#    [730, 731]],
#   [[732, 737],
#    [738, 740],
#    [741, 747],
#    [748, 756],
#    [757, 766],
#    [767, 769],
#    [770, 774],
#    [775, 780],
#    [781, 785],
#    [786, 793],
#    [793, 794],
#    [795, 800],
#    [801, 804],
#    [805, 814],
#    [815, 823],
#    [824, 835],
#    [836, 842],
#    [843, 856],
#    [856, 857]],
#   [[858, 863],
#    [864, 871],
#    [872, 874],
#    [875, 877],
#    [878, 879],
#    [880, 885],
#    [886, 898],
#    [899, 903],
#    [903, 904],
#    [904, 909],
#    [910, 917],
#    [918, 926],
#    [926, 927]],
#   [[928, 937], [938, 948], [949, 951], [952, 960], [961, 973], [973, 974]]],
#  'split_sents': ['Single view chest dated 2/11/2000 at 20:11 hours: Unchanged appearance of left basilar opacity.',
#   'The left basilar opacity may represent atelectasis.',
#   'The left basilar opacity may represent consolidation.',
#   'No pleural effusion.',
#   'No pneumothorax.',
#   'Unchanged moderate cardiomegaly.',
#   'Radiopaque marker is visualized at level of left eighth posterior rib.',
#   'Unchanged appearance of other lines and tubes.',
#   'The endotracheal tube is unchanged.',
#   'The Swan-Ganz catheter with tip in main pulmonary artery is unchanged.',
#   'Multiple thoracic drains are unchanged.',
#   'Radiopaque object is seen over the superior mediastinum.',
#   'The radiopaque object likely represents a retained pacemaker fragment.',
#   'Single view chest dated 2-11-2000:',
#   'There has been interval placement of a transesophageal echo probe.',
#   'Unchanged appearance of other lines.',
#   'Unchanged appearance of tubes as described above.',
#   'There is slight interval worsening of left lower lobe opacity.',
#   'The interval worsening may represent worsened atelectasis.',
#   'The interval worsening may represent consolidation.',
#   'There appears to be a small pleural effusion.',
#   'The pleural effusion is left-sided.',
#   'Unchanged appearance of moderate cardiomegaly.'],
#  'split_sent_toks': [['Single',
#    'view',
#    'chest',
#    'dated',
#    '2/11/2000',
#    'at',
#    '20:11',
#    'hours',
#    ':',
#    'Unchanged',
#    'appearance',
#    'of',
#    'left',
#    'basilar',
#    'opacity',
#    '.'],
#   ['The',
#    'left',
#    'basilar',
#    'opacity',
#    'may',
#    'represent',
#    'atelectasis',
#    '.'],
#   ['The',
#    'left',
#    'basilar',
#    'opacity',
#    'may',
#    'represent',
#    'consolidation',
#    '.'],
#   ['No', 'pleural', 'effusion', '.'],
#   ['No', 'pneumothorax', '.'],
#   ['Unchanged', 'moderate', 'cardiomegaly', '.'],
#   ['Radiopaque',
#    'marker',
#    'is',
#    'visualized',
#    'at',
#    'level',
#    'of',
#    'left',
#    'eighth',
#    'posterior',
#    'rib',
#    '.'],
#   ['Unchanged', 'appearance', 'of', 'other', 'lines', 'and', 'tubes', '.'],
#   ['The', 'endotracheal', 'tube', 'is', 'unchanged', '.'],
#   ['The',
#    'Swan',
#    '-',
#    'Ganz',
#    'catheter',
#    'with',
#    'tip',
#    'in',
#    'main',
#    'pulmonary',
#    'artery',
#    'is',
#    'unchanged',
#    '.'],
#   ['Multiple', 'thoracic', 'drains', 'are', 'unchanged', '.'],
#   ['Radiopaque',
#    'object',
#    'is',
#    'seen',
#    'over',
#    'the',
#    'superior',
#    'mediastinum',
#    '.'],
#   ['The',
#    'radiopaque',
#    'object',
#    'likely',
#    'represents',
#    'a',
#    'retained',
#    'pacemaker',
#    'fragment',
#    '.'],
#   ['Single', 'view', 'chest', 'dated', '2', '-', '11', '-', '2000', ':'],
#   ['There',
#    'has',
#    'been',
#    'interval',
#    'placement',
#    'of',
#    'a',
#    'transesophageal',
#    'echo',
#    'probe',
#    '.'],
#   ['Unchanged', 'appearance', 'of', 'other', 'lines', '.'],
#   ['Unchanged', 'appearance', 'of', 'tubes', 'as', 'described', 'above', '.'],
#   ['There',
#    'is',
#    'slight',
#    'interval',
#    'worsening',
#    'of',
#    'left',
#    'lower',
#    'lobe',
#    'opacity',
#    '.'],
#   ['The',
#    'interval',
#    'worsening',
#    'may',
#    'represent',
#    'worsened',
#    'atelectasis',
#    '.'],
#   ['The', 'interval', 'worsening', 'may', 'represent', 'consolidation', '.'],
#   ['There', 'appears', 'to', 'be', 'a', 'small', 'pleural', 'effusion', '.'],
#   ['The', 'pleural', 'effusion', 'is', 'left', '-', 'sided', '.'],
#   ['Unchanged', 'appearance', 'of', 'moderate', 'cardiomegaly', '.']],
#  'sent_idx_split_idx': [[0, 0],
#   [0, 1],
#   [0, 2],
#   [1, 0],
#   [1, 1],
#   [2, 0],
#   [3, 0],
#   [4, 0],
#   [4, 1],
#   [4, 2],
#   [4, 3],
#   [5, 0],
#   [5, 1],
#   [6, 0],
#   [6, 1],
#   [7, 0],
#   [7, 1],
#   [8, 0],
#   [8, 1],
#   [8, 2],
#   [9, 0],
#   [9, 1],
#   [10, 0]],
#  'radlex': [[{'char_indices': [0, 6],
#     'match_type': 'lower_text',
#     'matched_text': 'Single',
#     'radlex_id': 'http://radlex.org/RID/RID5762',
#     'radlex_name': 'single',
#     'tok_indices': [0, 1]},
#    {'char_indices': [12, 17],
#     'match_type': 'lower_text',
#     'matched_text': 'chest',
#     'radlex_id': 'http://radlex.org/RID/RID1243',
#     'radlex_name': 'thorax',
#     'tok_indices': [2, 3]},
#    {'char_indices': [50, 59],
#     'match_type': 'lower_text',
#     'matched_text': 'Unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [9, 10]},
#    {'char_indices': [60, 70],
#     'match_type': 'lower_text',
#     'matched_text': 'appearance',
#     'radlex_id': 'http://radlex.org/RID/RID49903',
#     'radlex_name': 'appearance',
#     'tok_indices': [10, 11]},
#    {'char_indices': [74, 78],
#     'match_type': 'lower_text',
#     'matched_text': 'left',
#     'radlex_id': 'http://radlex.org/RID/RID5824',
#     'radlex_name': 'left',
#     'tok_indices': [12, 13]},
#    {'char_indices': [79, 86],
#     'match_type': 'lower_text',
#     'matched_text': 'basilar',
#     'radlex_id': 'http://radlex.org/RID/RID5834',
#     'radlex_name': 'basilar',
#     'tok_indices': [13, 14]},
#    {'char_indices': [87, 94],
#     'match_type': 'lower_text',
#     'matched_text': 'opacity',
#     'radlex_id': 'http://radlex.org/RID/RID28530',
#     'radlex_name': 'opacity',
#     'tok_indices': [14, 15]}],
#   [{'char_indices': [4, 8],
#     'match_type': 'lower_text',
#     'matched_text': 'left',
#     'radlex_id': 'http://radlex.org/RID/RID5824',
#     'radlex_name': 'left',
#     'tok_indices': [1, 2]},
#    {'char_indices': [9, 16],
#     'match_type': 'lower_text',
#     'matched_text': 'basilar',
#     'radlex_id': 'http://radlex.org/RID/RID5834',
#     'radlex_name': 'basilar',
#     'tok_indices': [2, 3]},
#    {'char_indices': [17, 24],
#     'match_type': 'lower_text',
#     'matched_text': 'opacity',
#     'radlex_id': 'http://radlex.org/RID/RID28530',
#     'radlex_name': 'opacity',
#     'tok_indices': [3, 4]},
#    {'char_indices': [39, 50],
#     'match_type': 'lower_text',
#     'matched_text': 'atelectasis',
#     'radlex_id': 'http://radlex.org/RID/RID28493',
#     'radlex_name': 'atelectasis',
#     'tok_indices': [6, 7]}],
#   [{'char_indices': [4, 8],
#     'match_type': 'lower_text',
#     'matched_text': 'left',
#     'radlex_id': 'http://radlex.org/RID/RID5824',
#     'radlex_name': 'left',
#     'tok_indices': [1, 2]},
#    {'char_indices': [9, 16],
#     'match_type': 'lower_text',
#     'matched_text': 'basilar',
#     'radlex_id': 'http://radlex.org/RID/RID5834',
#     'radlex_name': 'basilar',
#     'tok_indices': [2, 3]},
#    {'char_indices': [17, 24],
#     'match_type': 'lower_text',
#     'matched_text': 'opacity',
#     'radlex_id': 'http://radlex.org/RID/RID28530',
#     'radlex_name': 'opacity',
#     'tok_indices': [3, 4]},
#    {'char_indices': [39, 52],
#     'match_type': 'lower_text',
#     'matched_text': 'consolidation',
#     'radlex_id': 'http://radlex.org/RID/RID43255',
#     'radlex_name': 'consolidation',
#     'tok_indices': [6, 7]}],
#   [{'char_indices': [0, 2],
#     'match_type': 'lower_text',
#     'matched_text': 'No',
#     'radlex_id': 'http://radlex.org/RID/RID28475',
#     'radlex_name': 'no',
#     'tok_indices': [0, 1]},
#    {'char_indices': [3, 19],
#     'match_type': 'lower_text',
#     'matched_text': 'pleural effusion',
#     'radlex_id': 'http://radlex.org/RID/RID34539',
#     'radlex_name': 'pleural effusion',
#     'tok_indices': [1, 3]},
#    {'char_indices': [11, 19],
#     'match_type': 'lower_text',
#     'matched_text': 'effusion',
#     'radlex_id': 'http://radlex.org/RID/RID4872',
#     'radlex_name': 'effusion',
#     'tok_indices': [2, 3]}],
#   [{'char_indices': [0, 2],
#     'match_type': 'lower_text',
#     'matched_text': 'No',
#     'radlex_id': 'http://radlex.org/RID/RID28475',
#     'radlex_name': 'no',
#     'tok_indices': [0, 1]},
#    {'char_indices': [3, 15],
#     'match_type': 'lower_text',
#     'matched_text': 'pneumothorax',
#     'radlex_id': 'http://radlex.org/RID/RID5352',
#     'radlex_name': 'pneumothorax',
#     'tok_indices': [1, 2]}],
#   [{'char_indices': [0, 9],
#     'match_type': 'lower_text',
#     'matched_text': 'Unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [0, 1]},
#    {'char_indices': [10, 18],
#     'match_type': 'lower_text',
#     'matched_text': 'moderate',
#     'radlex_id': 'http://radlex.org/RID/RID5672',
#     'radlex_name': 'moderate',
#     'tok_indices': [1, 2]}],
#   [{'char_indices': [0, 10],
#     'match_type': 'lower_text',
#     'matched_text': 'Radiopaque',
#     'radlex_id': 'http://radlex.org/RID/RID6035',
#     'radlex_name': 'radiopaque',
#     'tok_indices': [0, 1]},
#    {'char_indices': [11, 17],
#     'match_type': 'lower_text',
#     'matched_text': 'marker',
#     'radlex_id': 'http://radlex.org/RID/RID49905',
#     'radlex_name': 'marker',
#     'tok_indices': [1, 2]},
#    {'char_indices': [44, 48],
#     'match_type': 'lower_text',
#     'matched_text': 'left',
#     'radlex_id': 'http://radlex.org/RID/RID5824',
#     'radlex_name': 'left',
#     'tok_indices': [7, 8]},
#    {'char_indices': [49, 55],
#     'match_type': 'lower_text',
#     'matched_text': 'eighth',
#     'radlex_id': 'http://radlex.org/RID/RID6010',
#     'radlex_name': '8th',
#     'tok_indices': [8, 9]},
#    {'char_indices': [56, 65],
#     'match_type': 'lower_text',
#     'matched_text': 'posterior',
#     'radlex_id': 'http://radlex.org/RID/RID5819',
#     'radlex_name': 'posterior',
#     'tok_indices': [9, 10]},
#    {'char_indices': [56, 69],
#     'match_type': 'lower_text',
#     'matched_text': 'posterior rib',
#     'radlex_id': 'http://radlex.org/RID/RID28580',
#     'radlex_name': 'posterior rib',
#     'tok_indices': [9, 11]},
#    {'char_indices': [66, 69],
#     'match_type': 'lower_text',
#     'matched_text': 'rib',
#     'radlex_id': 'http://radlex.org/RID/RID2471',
#     'radlex_name': 'rib',
#     'tok_indices': [10, 11]}],
#   [{'char_indices': [0, 9],
#     'match_type': 'lower_text',
#     'matched_text': 'Unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [0, 1]},
#    {'char_indices': [10, 20],
#     'match_type': 'lower_text',
#     'matched_text': 'appearance',
#     'radlex_id': 'http://radlex.org/RID/RID49903',
#     'radlex_name': 'appearance',
#     'tok_indices': [1, 2]},
#    {'char_indices': [30, 35],
#     'match_type': 'lemma',
#     'matched_text': 'lines',
#     'radlex_id': 'http://radlex.org/RID/RID5965',
#     'radlex_name': 'lining',
#     'tok_indices': [4, 5]},
#    {'char_indices': [40, 45],
#     'match_type': 'lemma',
#     'matched_text': 'tubes',
#     'radlex_id': 'http://radlex.org/RID/RID5555',
#     'radlex_name': 'tube',
#     'tok_indices': [6, 7]}],
#   [{'char_indices': [4, 16],
#     'match_type': 'lower_text',
#     'matched_text': 'endotracheal',
#     'radlex_id': 'http://radlex.org/RID/RID11098',
#     'radlex_name': 'endotracheal',
#     'tok_indices': [1, 2]},
#    {'char_indices': [4, 21],
#     'match_type': 'lower_text',
#     'matched_text': 'endotracheal tube',
#     'radlex_id': 'http://radlex.org/RID/RID5557',
#     'radlex_name': 'endotracheal tube',
#     'tok_indices': [1, 3]},
#    {'char_indices': [17, 21],
#     'match_type': 'lower_text',
#     'matched_text': 'tube',
#     'radlex_id': 'http://radlex.org/RID/RID5555',
#     'radlex_name': 'tube',
#     'tok_indices': [2, 3]},
#    {'char_indices': [25, 34],
#     'match_type': 'lower_text',
#     'matched_text': 'unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [4, 5]}],
#   [{'char_indices': [4, 22],
#     'match_type': 'lower_text',
#     'matched_text': 'Swan-Ganz catheter',
#     'radlex_id': 'http://radlex.org/RID/RID5584',
#     'radlex_name': 'Swan-Ganz catheter',
#     'tok_indices': [1, 5]},
#    {'char_indices': [14, 22],
#     'match_type': 'lower_text',
#     'matched_text': 'catheter',
#     'radlex_id': 'http://radlex.org/RID/RID5576',
#     'radlex_name': 'catheter',
#     'tok_indices': [4, 5]},
#    {'char_indices': [23, 27],
#     'match_type': 'lower_text',
#     'matched_text': 'with',
#     'radlex_id': 'http://radlex.org/RID/RID49853',
#     'radlex_name': 'with',
#     'tok_indices': [5, 6]},
#    {'char_indices': [35, 56],
#     'match_type': 'lower_text',
#     'matched_text': 'main pulmonary artery',
#     'radlex_id': 'http://radlex.org/RID/RID975',
#     'radlex_name': 'main pulmonary artery',
#     'tok_indices': [8, 11]},
#    {'char_indices': [40, 56],
#     'match_type': 'lower_text',
#     'matched_text': 'pulmonary artery',
#     'radlex_id': 'http://radlex.org/RID/RID974',
#     'radlex_name': 'pulmonary artery',
#     'tok_indices': [9, 11]},
#    {'char_indices': [50, 56],
#     'match_type': 'lower_text',
#     'matched_text': 'artery',
#     'radlex_id': 'http://radlex.org/RID/RID478',
#     'radlex_name': 'artery',
#     'tok_indices': [10, 11]},
#    {'char_indices': [60, 69],
#     'match_type': 'lower_text',
#     'matched_text': 'unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [12, 13]}],
#   [{'char_indices': [0, 8],
#     'match_type': 'lower_text',
#     'matched_text': 'Multiple',
#     'radlex_id': 'http://radlex.org/RID/RID5765',
#     'radlex_name': 'multiple',
#     'tok_indices': [0, 1]},
#    {'char_indices': [18, 24],
#     'match_type': 'lemma',
#     'matched_text': 'drains',
#     'radlex_id': 'http://radlex.org/RID/RID5610',
#     'radlex_name': 'surgical drain',
#     'tok_indices': [2, 3]},
#    {'char_indices': [29, 38],
#     'match_type': 'lower_text',
#     'matched_text': 'unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [4, 5]}],
#   [{'char_indices': [0, 10],
#     'match_type': 'lower_text',
#     'matched_text': 'Radiopaque',
#     'radlex_id': 'http://radlex.org/RID/RID6035',
#     'radlex_name': 'radiopaque',
#     'tok_indices': [0, 1]},
#    {'char_indices': [11, 17],
#     'match_type': 'lower_text',
#     'matched_text': 'object',
#     'radlex_id': 'http://radlex.org/RID/RID34861',
#     'radlex_name': 'object',
#     'tok_indices': [1, 2]},
#    {'char_indices': [35, 43],
#     'match_type': 'lower_text',
#     'matched_text': 'superior',
#     'radlex_id': 'http://radlex.org/RID/RID5822',
#     'radlex_name': 'superior',
#     'tok_indices': [6, 7]},
#    {'char_indices': [35, 55],
#     'match_type': 'lower_text',
#     'matched_text': 'superior mediastinum',
#     'radlex_id': 'http://radlex.org/RID/RID28742',
#     'radlex_name': 'superior mediastinum',
#     'tok_indices': [6, 8]},
#    {'char_indices': [44, 55],
#     'match_type': 'lower_text',
#     'matched_text': 'mediastinum',
#     'radlex_id': 'http://radlex.org/RID/RID1384',
#     'radlex_name': 'mediastinum',
#     'tok_indices': [7, 8]}],
#   [{'char_indices': [4, 14],
#     'match_type': 'lower_text',
#     'matched_text': 'radiopaque',
#     'radlex_id': 'http://radlex.org/RID/RID6035',
#     'radlex_name': 'radiopaque',
#     'tok_indices': [1, 2]},
#    {'char_indices': [15, 21],
#     'match_type': 'lower_text',
#     'matched_text': 'object',
#     'radlex_id': 'http://radlex.org/RID/RID34861',
#     'radlex_name': 'object',
#     'tok_indices': [2, 3]},
#    {'char_indices': [51, 60],
#     'match_type': 'lower_text',
#     'matched_text': 'pacemaker',
#     'radlex_id': 'http://radlex.org/RID/RID5436',
#     'radlex_name': 'pacemaker',
#     'tok_indices': [7, 8]}],
#   [{'char_indices': [0, 6],
#     'match_type': 'lower_text',
#     'matched_text': 'Single',
#     'radlex_id': 'http://radlex.org/RID/RID5762',
#     'radlex_name': 'single',
#     'tok_indices': [0, 1]},
#    {'char_indices': [12, 17],
#     'match_type': 'lower_text',
#     'matched_text': 'chest',
#     'radlex_id': 'http://radlex.org/RID/RID1243',
#     'radlex_name': 'thorax',
#     'tok_indices': [2, 3]}],
#   [{'char_indices': [60, 65],
#     'match_type': 'lower_text',
#     'matched_text': 'probe',
#     'radlex_id': 'http://radlex.org/RID/RID45649',
#     'radlex_name': 'probe',
#     'tok_indices': [9, 10]}],
#   [{'char_indices': [0, 9],
#     'match_type': 'lower_text',
#     'matched_text': 'Unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [0, 1]},
#    {'char_indices': [10, 20],
#     'match_type': 'lower_text',
#     'matched_text': 'appearance',
#     'radlex_id': 'http://radlex.org/RID/RID49903',
#     'radlex_name': 'appearance',
#     'tok_indices': [1, 2]},
#    {'char_indices': [30, 35],
#     'match_type': 'lemma',
#     'matched_text': 'lines',
#     'radlex_id': 'http://radlex.org/RID/RID5965',
#     'radlex_name': 'lining',
#     'tok_indices': [4, 5]}],
#   [{'char_indices': [0, 9],
#     'match_type': 'lower_text',
#     'matched_text': 'Unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [0, 1]},
#    {'char_indices': [10, 20],
#     'match_type': 'lower_text',
#     'matched_text': 'appearance',
#     'radlex_id': 'http://radlex.org/RID/RID49903',
#     'radlex_name': 'appearance',
#     'tok_indices': [1, 2]},
#    {'char_indices': [24, 29],
#     'match_type': 'lemma',
#     'matched_text': 'tubes',
#     'radlex_id': 'http://radlex.org/RID/RID5555',
#     'radlex_name': 'tube',
#     'tok_indices': [3, 4]}],
#   [{'char_indices': [25, 34],
#     'match_type': 'lower_text',
#     'matched_text': 'worsening',
#     'radlex_id': 'http://radlex.org/RID/RID39271',
#     'radlex_name': 'worsening',
#     'tok_indices': [4, 5]},
#    {'char_indices': [38, 42],
#     'match_type': 'lower_text',
#     'matched_text': 'left',
#     'radlex_id': 'http://radlex.org/RID/RID5824',
#     'radlex_name': 'left',
#     'tok_indices': [6, 7]},
#    {'char_indices': [38, 53],
#     'match_type': 'lower_text',
#     'matched_text': 'left lower lobe',
#     'radlex_id': 'http://radlex.org/RID/RID1338',
#     'radlex_name': 'lower lobe of left lung',
#     'tok_indices': [6, 9]},
#    {'char_indices': [43, 48],
#     'match_type': 'lower_text',
#     'matched_text': 'lower',
#     'radlex_id': 'http://radlex.org/RID/RID46058',
#     'radlex_name': 'lower',
#     'tok_indices': [7, 8]},
#    {'char_indices': [49, 53],
#     'match_type': 'lower_text',
#     'matched_text': 'lobe',
#     'radlex_id': 'http://radlex.org/RID/RID5967',
#     'radlex_name': 'lobe',
#     'tok_indices': [8, 9]},
#    {'char_indices': [54, 61],
#     'match_type': 'lower_text',
#     'matched_text': 'opacity',
#     'radlex_id': 'http://radlex.org/RID/RID28530',
#     'radlex_name': 'opacity',
#     'tok_indices': [9, 10]}],
#   [{'char_indices': [13, 22],
#     'match_type': 'lower_text',
#     'matched_text': 'worsening',
#     'radlex_id': 'http://radlex.org/RID/RID39271',
#     'radlex_name': 'worsening',
#     'tok_indices': [2, 3]},
#    {'char_indices': [37, 45],
#     'match_type': 'lemma',
#     'matched_text': 'worsened',
#     'radlex_id': 'http://radlex.org/RID/RID39271',
#     'radlex_name': 'worsening',
#     'tok_indices': [5, 6]},
#    {'char_indices': [46, 57],
#     'match_type': 'lower_text',
#     'matched_text': 'atelectasis',
#     'radlex_id': 'http://radlex.org/RID/RID28493',
#     'radlex_name': 'atelectasis',
#     'tok_indices': [6, 7]}],
#   [{'char_indices': [13, 22],
#     'match_type': 'lower_text',
#     'matched_text': 'worsening',
#     'radlex_id': 'http://radlex.org/RID/RID39271',
#     'radlex_name': 'worsening',
#     'tok_indices': [2, 3]},
#    {'char_indices': [37, 50],
#     'match_type': 'lower_text',
#     'matched_text': 'consolidation',
#     'radlex_id': 'http://radlex.org/RID/RID43255',
#     'radlex_name': 'consolidation',
#     'tok_indices': [5, 6]}],
#   [{'char_indices': [22, 27],
#     'match_type': 'lower_text',
#     'matched_text': 'small',
#     'radlex_id': 'http://radlex.org/RID/RID5774',
#     'radlex_name': 'small',
#     'tok_indices': [5, 6]},
#    {'char_indices': [28, 44],
#     'match_type': 'lower_text',
#     'matched_text': 'pleural effusion',
#     'radlex_id': 'http://radlex.org/RID/RID34539',
#     'radlex_name': 'pleural effusion',
#     'tok_indices': [6, 8]},
#    {'char_indices': [36, 44],
#     'match_type': 'lower_text',
#     'matched_text': 'effusion',
#     'radlex_id': 'http://radlex.org/RID/RID4872',
#     'radlex_name': 'effusion',
#     'tok_indices': [7, 8]}],
#   [{'char_indices': [4, 20],
#     'match_type': 'lower_text',
#     'matched_text': 'pleural effusion',
#     'radlex_id': 'http://radlex.org/RID/RID34539',
#     'radlex_name': 'pleural effusion',
#     'tok_indices': [1, 3]},
#    {'char_indices': [12, 20],
#     'match_type': 'lower_text',
#     'matched_text': 'effusion',
#     'radlex_id': 'http://radlex.org/RID/RID4872',
#     'radlex_name': 'effusion',
#     'tok_indices': [2, 3]},
#    {'char_indices': [24, 28],
#     'match_type': 'lower_text',
#     'matched_text': 'left',
#     'radlex_id': 'http://radlex.org/RID/RID5824',
#     'radlex_name': 'left',
#     'tok_indices': [4, 5]}],
#   [{'char_indices': [0, 9],
#     'match_type': 'lower_text',
#     'matched_text': 'Unchanged',
#     'radlex_id': 'http://radlex.org/RID/RID39268',
#     'radlex_name': 'unchanged',
#     'tok_indices': [0, 1]},
#    {'char_indices': [10, 20],
#     'match_type': 'lower_text',
#     'matched_text': 'appearance',
#     'radlex_id': 'http://radlex.org/RID/RID49903',
#     'radlex_name': 'appearance',
#     'tok_indices': [1, 2]},
#    {'char_indices': [24, 32],
#     'match_type': 'lower_text',
#     'matched_text': 'moderate',
#     'radlex_id': 'http://radlex.org/RID/RID5672',
#     'radlex_name': 'moderate',
#     'tok_indices': [3, 4]}]],
#  'cxrgraph_ent': [[{'ent_toks': ['Unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [9, 10]},
#    {'ent_toks': ['appearance'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [10, 11]},
#    {'ent_toks': ['left'], 'ent_type': 'Anatomy', 'tok_indices': [12, 13]},
#    {'ent_toks': ['basilar'], 'ent_type': 'Anatomy', 'tok_indices': [13, 14]},
#    {'ent_toks': ['opacity'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [14, 15]}],
#   [{'ent_toks': ['left'], 'ent_type': 'Anatomy', 'tok_indices': [1, 2]},
#    {'ent_toks': ['basilar'], 'ent_type': 'Anatomy', 'tok_indices': [2, 3]},
#    {'ent_toks': ['opacity'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [3, 4]},
#    {'ent_toks': ['atelectasis'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [6, 7]}],
#   [{'ent_toks': ['left'], 'ent_type': 'Anatomy', 'tok_indices': [1, 2]},
#    {'ent_toks': ['basilar'], 'ent_type': 'Anatomy', 'tok_indices': [2, 3]},
#    {'ent_toks': ['opacity'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [3, 4]},
#    {'ent_toks': ['consolidation'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [6, 7]}],
#   [{'ent_toks': ['pleural'], 'ent_type': 'Anatomy', 'tok_indices': [1, 2]},
#    {'ent_toks': ['effusion'],
#     'ent_type': 'Observation-Absent',
#     'tok_indices': [2, 3]}],
#   [{'ent_toks': ['pneumothorax'],
#     'ent_type': 'Observation-Absent',
#     'tok_indices': [1, 2]}],
#   [{'ent_toks': ['Unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [0, 1]},
#    {'ent_toks': ['moderate'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['cardiomegaly'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]}],
#   [{'ent_toks': ['Radiopaque'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [0, 1]},
#    {'ent_toks': ['marker'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['level'], 'ent_type': 'Anatomy', 'tok_indices': [5, 6]},
#    {'ent_toks': ['left'], 'ent_type': 'Anatomy', 'tok_indices': [7, 8]},
#    {'ent_toks': ['eighth'], 'ent_type': 'Anatomy', 'tok_indices': [8, 9]},
#    {'ent_toks': ['posterior'], 'ent_type': 'Anatomy', 'tok_indices': [9, 10]},
#    {'ent_toks': ['rib'], 'ent_type': 'Anatomy', 'tok_indices': [10, 11]}],
#   [{'ent_toks': ['Unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [0, 1]},
#    {'ent_toks': ['appearance'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['other'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [3, 4]},
#    {'ent_toks': ['lines'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [4, 5]},
#    {'ent_toks': ['and'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [5, 6]},
#    {'ent_toks': ['tubes'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [6, 7]}],
#   [{'ent_toks': ['endotracheal'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['tube'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]},
#    {'ent_toks': ['unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [4, 5]}],
#   [{'ent_toks': ['Swan', '-', 'Ganz'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 4]},
#    {'ent_toks': ['catheter'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [4, 5]},
#    {'ent_toks': ['tip'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [6, 7]},
#    {'ent_toks': ['main'], 'ent_type': 'Anatomy', 'tok_indices': [8, 9]},
#    {'ent_toks': ['pulmonary'], 'ent_type': 'Anatomy', 'tok_indices': [9, 10]},
#    {'ent_toks': ['artery'], 'ent_type': 'Anatomy', 'tok_indices': [10, 11]},
#    {'ent_toks': ['unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [12, 13]}],
#   [{'ent_toks': ['Multiple'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [0, 1]},
#    {'ent_toks': ['thoracic'], 'ent_type': 'Anatomy', 'tok_indices': [1, 2]},
#    {'ent_toks': ['drains'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]},
#    {'ent_toks': ['unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [4, 5]}],
#   [{'ent_toks': ['Radiopaque'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [0, 1]},
#    {'ent_toks': ['object'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['over'],
#     'ent_type': 'Location-Attribute',
#     'tok_indices': [4, 5]},
#    {'ent_toks': ['superior'], 'ent_type': 'Anatomy', 'tok_indices': [6, 7]},
#    {'ent_toks': ['mediastinum'],
#     'ent_type': 'Anatomy',
#     'tok_indices': [7, 8]}],
#   [{'ent_toks': ['radiopaque'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['object'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]},
#    {'ent_toks': ['retained'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [6, 7]},
#    {'ent_toks': ['pacemaker'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [7, 8]},
#    {'ent_toks': ['fragment'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [8, 9]}],
#   [],
#   [{'ent_toks': ['transesophageal'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [7, 8]},
#    {'ent_toks': ['echo'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [8, 9]}],
#   [{'ent_toks': ['Unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [0, 1]},
#    {'ent_toks': ['appearance'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['of'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]},
#    {'ent_toks': ['other'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [3, 4]},
#    {'ent_toks': ['lines'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [4, 5]}],
#   [{'ent_toks': ['Unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [0, 1]},
#    {'ent_toks': ['appearance'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['tubes'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [3, 4]}],
#   [{'ent_toks': ['slight'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]},
#    {'ent_toks': ['worsening'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [4, 5]},
#    {'ent_toks': ['left'], 'ent_type': 'Anatomy', 'tok_indices': [6, 7]},
#    {'ent_toks': ['lower'], 'ent_type': 'Anatomy', 'tok_indices': [7, 8]},
#    {'ent_toks': ['lobe'], 'ent_type': 'Anatomy', 'tok_indices': [8, 9]},
#    {'ent_toks': ['opacity'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [9, 10]}],
#   [{'ent_toks': ['interval'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['worsening'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]},
#    {'ent_toks': ['worsened'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [5, 6]},
#    {'ent_toks': ['atelectasis'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [6, 7]}],
#   [{'ent_toks': ['interval'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['worsening'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]},
#    {'ent_toks': ['consolidation'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [5, 6]}],
#   [{'ent_toks': ['small'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [5, 6]},
#    {'ent_toks': ['pleural'], 'ent_type': 'Anatomy', 'tok_indices': [6, 7]},
#    {'ent_toks': ['effusion'],
#     'ent_type': 'Observation-Uncertain',
#     'tok_indices': [7, 8]}],
#   [{'ent_toks': ['pleural'], 'ent_type': 'Anatomy', 'tok_indices': [1, 2]},
#    {'ent_toks': ['effusion'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [2, 3]},
#    {'ent_toks': ['left'], 'ent_type': 'Anatomy', 'tok_indices': [4, 5]}],
#   [{'ent_toks': ['Unchanged'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [0, 1]},
#    {'ent_toks': ['appearance'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [1, 2]},
#    {'ent_toks': ['moderate'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [3, 4]},
#    {'ent_toks': ['cardiomegaly'],
#     'ent_type': 'Observation-Present',
#     'tok_indices': [4, 5]}]],
#  'cxrgraph_attr': [[{'attr_action': 'Removable',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['Unchanged'],
#     'tok_indices': [9, 10]}],
#   [],
#   [],
#   [],
#   [],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['Unchanged'],
#     'tok_indices': [0, 1]}],
#   [],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['Unchanged'],
#     'tok_indices': [0, 1]}],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['unchanged'],
#     'tok_indices': [4, 5]}],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['unchanged'],
#     'tok_indices': [12, 13]}],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['unchanged'],
#     'tok_indices': [4, 5]}],
#   [],
#   [],
#   [],
#   [],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['Unchanged'],
#     'tok_indices': [0, 1]}],
#   [{'attr_action': 'NA',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['Unchanged'],
#     'tok_indices': [0, 1]}],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Negative',
#     'attr_normality': 'NA',
#     'ent_toks': ['worsening'],
#     'tok_indices': [4, 5]}],
#   [{'attr_action': 'Removable',
#     'attr_change': 'NA',
#     'attr_normality': 'NA',
#     'ent_toks': ['worsening'],
#     'tok_indices': [2, 3]},
#    {'attr_action': 'Removable',
#     'attr_change': 'NA',
#     'attr_normality': 'NA',
#     'ent_toks': ['worsened'],
#     'tok_indices': [5, 6]}],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Negative',
#     'attr_normality': 'NA',
#     'ent_toks': ['worsening'],
#     'tok_indices': [2, 3]}],
#   [],
#   [],
#   [{'attr_action': 'Removable',
#     'attr_change': 'Unchanged',
#     'attr_normality': 'NA',
#     'ent_toks': ['Unchanged'],
#     'tok_indices': [0, 1]}]],
#  'cxrgraph_rel': [[{'obj_tok_indices': [10, 11],
#     'obj_toks': ['appearance'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [9, 10],
#     'subj_toks': ['Unchanged']},
#    {'obj_tok_indices': [14, 15],
#     'obj_toks': ['opacity'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [10, 11],
#     'subj_toks': ['appearance']},
#    {'obj_tok_indices': [13, 14],
#     'obj_toks': ['basilar'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [12, 13],
#     'subj_toks': ['left']},
#    {'obj_tok_indices': [13, 14],
#     'obj_toks': ['basilar'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [14, 15],
#     'subj_toks': ['opacity']}],
#   [{'obj_tok_indices': [2, 3],
#     'obj_toks': ['basilar'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['left']},
#    {'obj_tok_indices': [6, 7],
#     'obj_toks': ['atelectasis'],
#     'rel_type': 'suggestive_of',
#     'subj_tok_indices': [3, 4],
#     'subj_toks': ['opacity']},
#    {'obj_tok_indices': [2, 3],
#     'obj_toks': ['basilar'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [3, 4],
#     'subj_toks': ['opacity']}],
#   [{'obj_tok_indices': [2, 3],
#     'obj_toks': ['basilar'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['left']},
#    {'obj_tok_indices': [6, 7],
#     'obj_toks': ['consolidation'],
#     'rel_type': 'suggestive_of',
#     'subj_tok_indices': [3, 4],
#     'subj_toks': ['opacity']},
#    {'obj_tok_indices': [2, 3],
#     'obj_toks': ['basilar'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [3, 4],
#     'subj_toks': ['opacity']}],
#   [{'obj_tok_indices': [1, 2],
#     'obj_toks': ['pleural'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [2, 3],
#     'subj_toks': ['effusion']}],
#   [],
#   [{'obj_tok_indices': [2, 3],
#     'obj_toks': ['cardiomegaly'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Unchanged']},
#    {'obj_tok_indices': [2, 3],
#     'obj_toks': ['cardiomegaly'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['moderate']}],
#   [{'obj_tok_indices': [1, 2],
#     'obj_toks': ['marker'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Radiopaque']},
#    {'obj_tok_indices': [5, 6],
#     'obj_toks': ['level'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['marker']},
#    {'obj_tok_indices': [10, 11],
#     'obj_toks': ['rib'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [5, 6],
#     'subj_toks': ['level']},
#    {'obj_tok_indices': [10, 11],
#     'obj_toks': ['rib'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [7, 8],
#     'subj_toks': ['left']},
#    {'obj_tok_indices': [10, 11],
#     'obj_toks': ['rib'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [8, 9],
#     'subj_toks': ['eighth']},
#    {'obj_tok_indices': [10, 11],
#     'obj_toks': ['rib'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [9, 10],
#     'subj_toks': ['posterior']}],
#   [{'obj_tok_indices': [1, 2],
#     'obj_toks': ['appearance'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Unchanged']},
#    {'obj_tok_indices': [6, 7],
#     'obj_toks': ['tubes'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['appearance']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['lines'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['appearance']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['lines'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [3, 4],
#     'subj_toks': ['other']},
#    {'obj_tok_indices': [6, 7],
#     'obj_toks': ['tubes'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [3, 4],
#     'subj_toks': ['other']},
#    {'obj_tok_indices': [6, 7],
#     'obj_toks': ['tubes'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [5, 6],
#     'subj_toks': ['and']}],
#   [{'obj_tok_indices': [2, 3],
#     'obj_toks': ['tube'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['endotracheal']},
#    {'obj_tok_indices': [2, 3],
#     'obj_toks': ['tube'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [4, 5],
#     'subj_toks': ['unchanged']}],
#   [{'obj_tok_indices': [4, 5],
#     'obj_toks': ['catheter'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [1, 4],
#     'subj_toks': ['Swan', '-', 'Ganz']},
#    {'obj_tok_indices': [10, 11],
#     'obj_toks': ['artery'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [6, 7],
#     'subj_toks': ['tip']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['catheter'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [6, 7],
#     'subj_toks': ['tip']},
#    {'obj_tok_indices': [10, 11],
#     'obj_toks': ['artery'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [8, 9],
#     'subj_toks': ['main']},
#    {'obj_tok_indices': [9, 10],
#     'obj_toks': ['pulmonary'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [10, 11],
#     'subj_toks': ['artery']},
#    {'obj_tok_indices': [6, 7],
#     'obj_toks': ['tip'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [12, 13],
#     'subj_toks': ['unchanged']}],
#   [{'obj_tok_indices': [2, 3],
#     'obj_toks': ['drains'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Multiple']},
#    {'obj_tok_indices': [1, 2],
#     'obj_toks': ['thoracic'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [2, 3],
#     'subj_toks': ['drains']},
#    {'obj_tok_indices': [2, 3],
#     'obj_toks': ['drains'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [4, 5],
#     'subj_toks': ['unchanged']}],
#   [{'obj_tok_indices': [1, 2],
#     'obj_toks': ['object'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Radiopaque']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['over'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['object']},
#    {'obj_tok_indices': [7, 8],
#     'obj_toks': ['mediastinum'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [4, 5],
#     'subj_toks': ['over']},
#    {'obj_tok_indices': [7, 8],
#     'obj_toks': ['mediastinum'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [6, 7],
#     'subj_toks': ['superior']}],
#   [{'obj_tok_indices': [2, 3],
#     'obj_toks': ['object'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['radiopaque']},
#    {'obj_tok_indices': [8, 9],
#     'obj_toks': ['fragment'],
#     'rel_type': 'suggestive_of',
#     'subj_tok_indices': [2, 3],
#     'subj_toks': ['object']},
#    {'obj_tok_indices': [8, 9],
#     'obj_toks': ['fragment'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [6, 7],
#     'subj_toks': ['retained']},
#    {'obj_tok_indices': [7, 8],
#     'obj_toks': ['pacemaker'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [8, 9],
#     'subj_toks': ['fragment']}],
#   [],
#   [],
#   [{'obj_tok_indices': [1, 2],
#     'obj_toks': ['appearance'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Unchanged']},
#    {'obj_tok_indices': [2, 3],
#     'obj_toks': ['of'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Unchanged']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['lines'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['appearance']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['lines'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [2, 3],
#     'subj_toks': ['of']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['lines'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [3, 4],
#     'subj_toks': ['other']}],
#   [{'obj_tok_indices': [1, 2],
#     'obj_toks': ['appearance'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Unchanged']},
#    {'obj_tok_indices': [3, 4],
#     'obj_toks': ['tubes'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['appearance']}],
#   [{'obj_tok_indices': [4, 5],
#     'obj_toks': ['worsening'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [2, 3],
#     'subj_toks': ['slight']},
#    {'obj_tok_indices': [9, 10],
#     'obj_toks': ['opacity'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [4, 5],
#     'subj_toks': ['worsening']},
#    {'obj_tok_indices': [8, 9],
#     'obj_toks': ['lobe'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [6, 7],
#     'subj_toks': ['left']},
#    {'obj_tok_indices': [8, 9],
#     'obj_toks': ['lobe'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [7, 8],
#     'subj_toks': ['lower']},
#    {'obj_tok_indices': [8, 9],
#     'obj_toks': ['lobe'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [9, 10],
#     'subj_toks': ['opacity']}],
#   [{'obj_tok_indices': [2, 3],
#     'obj_toks': ['worsening'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['interval']},
#    {'obj_tok_indices': [6, 7],
#     'obj_toks': ['atelectasis'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [5, 6],
#     'subj_toks': ['worsened']}],
#   [{'obj_tok_indices': [2, 3],
#     'obj_toks': ['worsening'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['interval']},
#    {'obj_tok_indices': [5, 6],
#     'obj_toks': ['consolidation'],
#     'rel_type': 'suggestive_of',
#     'subj_tok_indices': [2, 3],
#     'subj_toks': ['worsening']}],
#   [{'obj_tok_indices': [7, 8],
#     'obj_toks': ['effusion'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [5, 6],
#     'subj_toks': ['small']},
#    {'obj_tok_indices': [6, 7],
#     'obj_toks': ['pleural'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [7, 8],
#     'subj_toks': ['effusion']}],
#   [{'obj_tok_indices': [1, 2],
#     'obj_toks': ['pleural'],
#     'rel_type': 'located_at',
#     'subj_tok_indices': [2, 3],
#     'subj_toks': ['effusion']},
#    {'obj_tok_indices': [1, 2],
#     'obj_toks': ['pleural'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [4, 5],
#     'subj_toks': ['left']}],
#   [{'obj_tok_indices': [1, 2],
#     'obj_toks': ['appearance'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [0, 1],
#     'subj_toks': ['Unchanged']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['cardiomegaly'],
#     'rel_type': 'part_of',
#     'subj_tok_indices': [1, 2],
#     'subj_toks': ['appearance']},
#    {'obj_tok_indices': [4, 5],
#     'obj_toks': ['cardiomegaly'],
#     'rel_type': 'modify',
#     'subj_tok_indices': [3, 4],
#     'subj_toks': ['moderate']}]],
#  'radcoref': [[{'mention_toks': ['left', 'basilar', 'opacity'],
#     'target_sent_idx': 0,
#     'tok_indices': [12, 15]},
#    {'mention_toks': ['The', 'left', 'basilar', 'opacity'],
#     'target_sent_idx': 1,
#     'tok_indices': [16, 20]},
#    {'mention_toks': ['The', 'left', 'basilar', 'opacity'],
#     'target_sent_idx': 2,
#     'tok_indices': [24, 28]}],
#   [{'mention_toks': ['Radiopaque', 'object'],
#     'target_sent_idx': 11,
#     'tok_indices': [89, 91]},
#    {'mention_toks': ['The', 'radiopaque', 'object'],
#     'target_sent_idx': 12,
#     'tok_indices': [98, 101]}],
#   [{'mention_toks': ['slight',
#      'interval',
#      'worsening',
#      'of',
#      'left',
#      'lower',
#      'lobe',
#      'opacity'],
#     'target_sent_idx': 17,
#     'tok_indices': [145, 153]},
#    {'mention_toks': ['The', 'interval', 'worsening'],
#     'target_sent_idx': 18,
#     'tok_indices': [154, 157]},
#    {'mention_toks': ['The', 'interval', 'worsening'],
#     'target_sent_idx': 19,
#     'tok_indices': [162, 165]}],
#   [{'mention_toks': ['a', 'small', 'pleural', 'effusion'],
#     'target_sent_idx': 20,
#     'tok_indices': [173, 177]},
#    {'mention_toks': ['The', 'pleural', 'effusion'],
#     'target_sent_idx': 21,
#     'tok_indices': [178, 181]}]]}

# %%
for data_split in ["train", "validation", "test"]:
    reprs = get_repr_tuples(hf_dataset=ds_text, data_split=data_split)
    print_statistic(reprs, data_split)

# [test] Unique sent tuples: 714
# [test] Unique tuples: 993
# 这意味着有一些 tuples 并非单独出现，而是与其他tuples组合一起出现的，所以才会tuples数量小于sent tuples数量
# Out:
# 100%|██████████| 343738/343738 [06:42<00:00, 854.15it/s]
# [train] Total sents: 2510741
# [train] Unique sents: 889686
# [train] Unique sent tuples: 483416
# [train] Unique tuples: 232428
# [train] Unique ent texts: 19386
#
# [train] Unique sent tuples (rm attr): 481262
# [train] Unique tuples (rm attr): 231176
# [train] Unique ent texts (rm attr): 19386
# 100%|██████████| 8825/8825 [00:09<00:00, 897.82it/s]
# [validation] Total sents: 64107
# [validation] Unique sents: 36894
# [validation] Unique sent tuples: 24469
# [validation] Unique tuples: 28243
# [validation] Unique ent texts: 4345
#
# [validation] Unique sent tuples (rm attr): 24376
# [validation] Unique tuples (rm attr): 28044
# [validation] Unique ent texts (rm attr): 4345
# 100%|██████████| 2692/2692 [00:04<00:00, 562.30it/s]
# [test] Total sents: 28072
# [test] Unique sents: 17133
# [test] Unique sent tuples: 11839
# [test] Unique tuples: 15157
# [test] Unique ent texts: 2661
#
# [test] Unique sent tuples (rm attr): 11800
# [test] Unique tuples (rm attr): 15039
# [test] Unique ent texts (rm attr): 2661
